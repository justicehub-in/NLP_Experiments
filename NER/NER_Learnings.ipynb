# %% [markdown]
# # Named Entity Recognition (NER)
#
# NER is an algorithm/logic that helps you identify "Entities" in the text.
#
# ## What are Named Entities?
# Every text comprises of various Entities. Few general entities that can be found in any text are "Name of a Person", "Location" etc., But, there could be specialised Entities specific to certain kind of texts. For example, court judgements might have entities like "Court", "Petitioner" etc.
#
# ## What are the advantages of building an NER system?
#
# ### Increased search relevance:
# Currently search is mostly done using keywords. If a particular keyword is present in a text, that text would be selected. But often the keyword may not belong to the required entity. For example, you want to read all articles about "Tesla" which belongs to the "COMPANY" entity. But a keyword search would also show you articles on "Nikola Tesla". NER based search would thus increase search relevance.
#
# ### Information Extraction and accelerated pace of pattern recognition:
# The naive way of extracting information from text is reading the text. But what if there are 1000s of similar texts? In a pre-AI world, expertise over a topic is gained by the experience of spending more time with a particular kind of texts. An expert property lawyer must have read 100s of texts (court judgements etc) relevant to property disputes; an expert cardiologist must have read 100s of articles related to cardiology. These experts, as a result of the time they spend with their texts, develop mental patterns which are highly valuable. An expert property lawyer or a cardiologist can quickly diagnose your predicament and provide a range of solutions. NER enables such pattern recognition from a large number of texts. If I'm a budding property lawyer, I can now download all the property dispute cases; use a customised NER system devloped to extract information from such cases; and develop my own mental patterns quickly.

# %% [markdown]
# # Table of Contents
# 1. [SpaCy](#spacy)
#
# 2. [Building your own NERs](#customner) <br>
#     2.1 [Rule based NER](#rulener) <br>
#     2.2 [Machine learning based NER](#mlner)
#
# 3. [OpenNyai](#opennyai): A Custom NER built to recognise specialised entities from Indian court judgements.

# %% [markdown]
# ## SpaCy <a class="anchor" id="spacy"></a>

# %%
import spacy

# %%
#Load Spacy's pre-trained Small English NLP Model
nlp_spacy = spacy.load("en_core_web_sm")

# en_core_web_md -- Medium English
# en_core_web_lg -- Large English

# %%
# All components in the Spacy's English NLP Model
nlp_spacy.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#Sample court judgement
sample_text = open('SampleTexts/sample_judgment1.txt').read()

#Create the doc object by passing it through nlp pipeline.
doc = nlp_spacy(sample_text)

# %%
# Run NER on the Doc object
for ent in doc.ents:    
    print(ent.text, "|", ent.start_char,"|", ent.end_char,"|", ent.label_,"|", spacy.explain(ent.label_))
# Out:
# THE SUPREME COURT OF INDIA | 32 | 58 | ORG | Companies, agencies, institutions, etc.
# 2017 | 140 | 144 | DATE | Absolute or relative dates or periods
# APPELLANT(S | 224 | 235 | ORG | Companies, agencies, institutions, etc.
# KANUNGO | 286 | 293 | PERSON | People, including fictional
# RESPONDENT(S | 349 | 361 | PERSON | People, including fictional
# B.R. GAVAI | 398 | 408 | PERSON | People, including fictional
# 18th April 2012 | 467 | 482 | DATE | Absolute or relative dates or periods
# the High Court of Orissa in Arbitration Appeal No. | 521 | 571 | ORG | Companies, agencies, institutions, etc.
# 25 | 572 | 574 | CARDINAL | Numerals that do not fall under another type
# 2007 | 578 | 582 | DATE | Absolute or relative dates or periods
# 2 | 640 | 641 | CARDINAL | Numerals that do not fall under another type
# 3 kilometers | 771 | 783 | QUANTITY | Measurements, as of weight or distance
# Kanjipani | 810 | 819 | GPE | Countries, cities, states
# Kuntala | 823 | 830 | GPE | Countries, cities, states
# 16th December 1971 | 834 | 852 | DATE | Absolute or relative dates or periods
# one year | 890 | 898 | DATE | Absolute or relative dates or periods
# 15 | 914 | 916 | CARDINAL | Numerals that do not fall under another type
# December 1972 | 920 | 933 | DATE | Absolute or relative dates or periods
# Rs.4,59,330/­. | 959 | 973 | GPE | Countries, cities, states
# 30th August 1977 | 1068 | 1084 | DATE | Absolute or relative dates or periods
# 3 | 1162 | 1163 | CARDINAL | Numerals that do not fall under another type
# 25th July 1989 | 1184 | 1198 | DATE | Absolute or relative dates or periods
# 10 | 1305 | 1307 | CARDINAL | Numerals that do not fall under another type
# August 1989 | 1311 | 1322 | DATE | Absolute or relative dates or periods
# Rs.3,34,744/­ | 1369 | 1382 | DATE | Absolute or relative dates or periods
# O.S. | 1486 | 1490 | NORP | Nationalities or religious or political groups
# 206 | 1495 | 1498 | CARDINAL | Numerals that do not fall under another type
# 1989 | 1502 | 1506 | DATE | Absolute or relative dates or periods
# the Court of Civil | 1514 | 1532 | ORG | Companies, agencies, institutions, etc.
# Bhubaneswar | 1558 | 1569 | PERSON | People, including fictional
# Section 20 | 1623 | 1633 | LAW | Named documents made into laws.
# the Arbitration Act | 1637 | 1656 | LAW | Named documents made into laws.
# 1940 | 1658 | 1662 | DATE | Absolute or relative dates or periods
# the 1940 Act | 1676 | 1688 | WORK_OF_ART | Titles of books, songs, etc.
# 14th February 1990 | 1774 | 1792 | DATE | Absolute or relative dates or periods
# 1940 | 2051 | 2055 | DATE | Absolute or relative dates or periods
# the Arbitration and Conciliation Act | 2077 | 2113 | ORG | Companies, agencies, institutions, etc.
# 1996 | 2115 | 2119 | DATE | Absolute or relative dates or periods
# the 1996 Act | 2133 | 2145 | WORK_OF_ART | Titles of books, songs, etc.
# 4 | 2166 | 2167 | CARDINAL | Numerals that do not fall under another type
# 4th | 2401 | 2404 | ORDINAL | "first", "second", etc.
# February 2000 | 2405 | 2418 | DATE | Absolute or relative dates or periods
# MJC | 2498 | 2501 | ORG | Companies, agencies, institutions, etc.
# 36 | 2506 | 2508 | CARDINAL | Numerals that do not fall under another type
# Section 11 of the 1996 | 2523 | 2545 | LAW | Named documents made into laws.
# the High Court | 2557 | 2571 | ORG | Companies, agencies, institutions, etc.
# the High Court | 2634 | 2648 | ORG | Companies, agencies, institutions, etc.
# 15 | 2667 | 2669 | CARDINAL | Numerals that do not fall under another type
# October 2001 | 2673 | 2685 | DATE | Absolute or relative dates or periods
# S.K. Mohanty | 2735 | 2747 | PERSON | People, including fictional
# High Court | 2774 | 2784 | ORG | Companies, agencies, institutions, etc.
# 5 | 2805 | 2806 | CARDINAL | Numerals that do not fall under another type
# 15th March 2002 | 2811 | 2826 | DATE | Absolute or relative dates or periods
# 19.5% | 2916 | 2921 | PERCENT | Percentage, including "%"
# 1st April 1976 to 15th March 2002 | 2936 | 2969 | DATE | Absolute or relative dates or periods
# 24 | 3012 | 3014 | CARDINAL | Numerals that do not fall under another type
# August 2004 | 3018 | 3029 | DATE | Absolute or relative dates or periods
# Nos | 3081 | 3084 | PERSON | People, including fictional
# 1 | 3086 | 3087 | CARDINAL | Numerals that do not fall under another type
# 14 | 3092 | 3094 | CARDINAL | Numerals that do not fall under another type
# 1st April 1976 | 3172 | 3186 | DATE | Absolute or relative dates or periods
# 18% | 3227 | 3230 | PERCENT | Percentage, including "%"
# 18% | 3359 | 3362 | PERCENT | Percentage, including "%"
# two | 3403 | 3406 | CARDINAL | Numerals that do not fall under another type
# Arbitration Petition No | 3499 | 3522 | ORG | Companies, agencies, institutions, etc.
# 153 | 3524 | 3527 | CARDINAL | Numerals that do not fall under another type
# the Court of District | 3543 | 3564 | ORG | Companies, agencies, institutions, etc.
# Cuttack | 3572 | 3579 | ORG | Companies, agencies, institutions, etc.
# Section 34 of the 1996 | 3586 | 3608 | LAW | Named documents made into laws.
# 25 | 3682 | 3684 | CARDINAL | Numerals that do not fall under another type
# July 2007 | 3688 | 3697 | DATE | Absolute or relative dates or periods
# Section 37 of the 1996 | 3761 | 3783 | LAW | Named documents made into laws.
# the High Court | 3795 | 3809 | ORG | Companies, agencies, institutions, etc.
# 6 | 3913 | 3914 | CARDINAL | Numerals that do not fall under another type
# Sibo Sankar Mishra | 3935 | 3953 | PERSON | People, including fictional
# Ashok Panigrahi | 4018 | 4033 | PERSON | People, including fictional
# 7 | 4092 | 4093 | CARDINAL | Numerals that do not fall under another type
# Shri Mishra | 4095 | 4106 | PERSON | People, including fictional
# 1977 | 4204 | 4208 | DATE | Absolute or relative dates or periods
# 1989 | 4212 | 4216 | DATE | Absolute or relative dates or periods
# twelve years | 4280 | 4292 | DATE | Absolute or relative dates or periods
# the year 1990 to 2000 | 4450 | 4471 | DATE | Absolute or relative dates or periods
# 14th February 1990 | 4511 | 4529 | DATE | Absolute or relative dates or periods
# F­2 agreement | 4580 | 4593 | ORG | Companies, agencies, institutions, etc.
# 18% | 4744 | 4747 | PERCENT | Percentage, including "%"
# Rs.46,90,000/­ | 4827 | 4841 | GPE | Countries, cities, states
# almost five | 4845 | 4856 | CARDINAL | Numerals that do not fall under another type
# Rs.9,20,650/­. | 4896 | 4910 | GPE | Countries, cities, states
# Court | 4945 | 4950 | ORG | Companies, agencies, institutions, etc.
# Rajendra Construction Co. | 4967 | 4992 | ORG | Companies, agencies, institutions, etc.
# Maharashtra Housing & Area Development Authority | 4996 | 5044 | ORG | Companies, agencies, institutions, etc.
# 1 | 5056 | 5057 | CARDINAL | Numerals that do not fall under another type
# G. Harischandra Reddy | 5093 | 5114 | PERSON | People, including fictional
# Mcdermott International Inc. | 5132 | 5160 | ORG | Companies, agencies, institutions, etc.
# Standard Co. Ltd. | 5169 | 5186 | ORG | Companies, agencies, institutions, etc.
# the High Court | 5336 | 5350 | ORG | Companies, agencies, institutions, etc.
# 8 | 5398 | 5399 | CARDINAL | Numerals that do not fall under another type
# the High Court | 5610 | 5624 | ORG | Companies, agencies, institutions, etc.
# 2006 | 5670 | 5674 | DATE | Absolute or relative dates or periods
# 11 | 5676 | 5678 | CARDINAL | Numerals that do not fall under another type
# 7 | 5745 | 5746 | CARDINAL | Numerals that do not fall under another type
# Section 31 of the 1996 | 5751 | 5773 | LAW | Named documents made into laws.
# Bench | 5822 | 5827 | PERSON | People, including fictional
# Court | 5836 | 5841 | ORG | Companies, agencies, institutions, etc.
# Hyder Consulting | 5857 | 5873 | ORG | Companies, agencies, institutions, etc.
# State of Orissa Through | 5900 | 5923 | ORG | Companies, agencies, institutions, etc.
# 9 | 5998 | 5999 | CARDINAL | Numerals that do not fall under another type
# 31(7)(a | 6009 | 6016 | CARDINAL | Numerals that do not fall under another type
# 1996 | 6025 | 6029 | DATE | Absolute or relative dates or periods
# 31 | 6052 | 6054 | CARDINAL | Numerals that do not fall under another type
# …… | 6096 | 6098 | ORG | Companies, agencies, institutions, etc.
# 7)(a | 6102 | 6106 | CARDINAL | Numerals that do not fall under another type
# 10 | 6511 | 6513 | CARDINAL | Numerals that do not fall under another type
# 31(7)(a | 6541 | 6548 | CARDINAL | Numerals that do not fall under another type
# 1996 | 6557 | 6561 | DATE | Absolute or relative dates or periods
# Court | 6601 | 6606 | ORG | Companies, agencies, institutions, etc.
# Hyder Consulting | 6647 | 6663 | ORG | Companies, agencies, institutions, etc.
# Delhi Airport Metro Express Private Limited | 6689 | 6732 | FAC | Buildings, airports, highways, bridges, etc.
# Delhi Metro Rail Corporation5 | 6736 | 6765 | PERSON | People, including fictional
# 7 | 6808 | 6809 | CARDINAL | Numerals that do not fall under another type
# Section 31 of the 1996 | 6814 | 6836 | LAW | Named documents made into laws.
# 2 | 6872 | 6873 | CARDINAL | Numerals that do not fall under another type
# 549 | 6903 | 6906 | CARDINAL | Numerals that do not fall under another type
# 11 | 8215 | 8217 | CARDINAL | Numerals that do not fall under another type
# the High Court | 8306 | 8320 | ORG | Companies, agencies, institutions, etc.
# 18% | 8466 | 8469 | PERCENT | Percentage, including "%"
# 12 | 8614 | 8616 | CARDINAL | Numerals that do not fall under another type
# 30st August 1977 | 8687 | 8703 | DATE | Absolute or relative dates or periods
# twelve years | 8721 | 8733 | DATE | Absolute or relative dates or periods
# 25th July 1989 | 8746 | 8760 | DATE | Absolute or relative dates or periods
# 25th July 1989 | 8850 | 8864 | DATE | Absolute or relative dates or periods
# 13 | 9087 | 9089 | CARDINAL | Numerals that do not fall under another type
# 14 | 9132 | 9134 | CARDINAL | Numerals that do not fall under another type
# February 1990 | 9138 | 9151 | DATE | Absolute or relative dates or periods
# 4 | 9237 | 9238 | CARDINAL | Numerals that do not fall under another type
# February 2000 | 9242 | 9255 | DATE | Absolute or relative dates or periods
# 1996 | 9278 | 9282 | DATE | Absolute or relative dates or periods
# 4th | 9407 | 9410 | ORDINAL | "first", "second", etc.
# February 2000 | 9411 | 9424 | DATE | Absolute or relative dates or periods
# MJC | 9468 | 9471 | ORG | Companies, agencies, institutions, etc.
# 36 | 9476 | 9478 | CARDINAL | Numerals that do not fall under another type
# the High Court | 9494 | 9508 | ORG | Companies, agencies, institutions, etc.
# Section 11 of the 1996 | 9545 | 9567 | LAW | Named documents made into laws.
# 15 | 9600 | 9602 | CARDINAL | Numerals that do not fall under another type
# October 2001 | 9606 | 9618 | DATE | Absolute or relative dates or periods
# almost ten years | 9663 | 9679 | DATE | Absolute or relative dates or periods
# 14th February 1990 | 9801 | 9819 | DATE | Absolute or relative dates or periods
# 14 | 9999 | 10001 | CARDINAL | Numerals that do not fall under another type
# February 1990 | 10005 | 10018 | DATE | Absolute or relative dates or periods
# 4th | 10022 | 10025 | ORDINAL | "first", "second", etc.
# February 2000 | 10026 | 10039 | DATE | Absolute or relative dates or periods
# 14 | 10110 | 10112 | CARDINAL | Numerals that do not fall under another type
# Section 11 of the 1996 | 10438 | 10460 | LAW | Named documents made into laws.
# the High Court | 10472 | 10486 | ORG | Companies, agencies, institutions, etc.
# 15 | 10509 | 10511 | CARDINAL | Numerals that do not fall under another type
# October 2001 | 10515 | 10528 | DATE | Absolute or relative dates or periods
# 14 | 10623 | 10625 | CARDINAL | Numerals that do not fall under another type
# February 1990 to 15th October 2001 | 10629 | 10663 | DATE | Absolute or relative dates or periods
# 15 | 10666 | 10668 | CARDINAL | Numerals that do not fall under another type
# the High Court | 10793 | 10807 | ORG | Companies, agencies, institutions, etc.
# Court | 10876 | 10881 | ORG | Companies, agencies, institutions, etc.
# Rajendra Construction Co. | 10897 | 10922 | ORG | Companies, agencies, institutions, etc.
# 30 | 10934 | 10936 | CARDINAL | Numerals that do not fall under another type
# 18 per cent | 11076 | 11087 | MONEY | Monetary values, including unit
# Court | 11290 | 11295 | ORG | Companies, agencies, institutions, etc.
# Executive Engineer | 11387 | 11405 | ORG | Companies, agencies, institutions, etc.
# 2001 | 11462 | 11466 | DATE | Absolute or relative dates or periods
# 2 SCC 721 | 11468 | 11477 | CARDINAL | Numerals that do not fall under another type
# Irrigation Deptt | 11509 | 11525 | PERSON | People, including fictional
# Govt | 11528 | 11532 | ORG | Companies, agencies, institutions, etc.
# Orissa | 11537 | 11543 | PERSON | People, including fictional
# G.C. Roy | 11547 | 11555 | PERSON | People, including fictional
# 1992 | 11558 | 11562 | DATE | Absolute or relative dates or periods
# Hindustan Construction Co. Ltd. | 11607 | 11638 | ORG | Companies, agencies, institutions, etc.
# 1992 | 11657 | 11661 | DATE | Absolute or relative dates or periods
# 4 | 11663 | 11664 | CARDINAL | Numerals that do not fall under another type
# Bhagawati Oxygen Ltd. | 11680 | 11701 | ORG | Companies, agencies, institutions, etc.
# Hindustan Copper Ltd. | 11705 | 11726 | ORG | Companies, agencies, institutions, etc.
# 2005 | 11729 | 11733 | DATE | Absolute or relative dates or periods
# 6 SCC 462 | 11735 | 11744 | QUANTITY | Measurements, as of weight or distance
# AIR 2005 | 11747 | 11755 | ORG | Companies, agencies, institutions, etc.
# 2005 | 11770 | 11774 | DATE | Absolute or relative dates or periods
# 4 | 11776 | 11777 | CARDINAL | Numerals that do not fall under another type
# C.K. Thakker | 11798 | 11810 | PERSON | People, including fictional
# J. | 11812 | 11814 | ORG | Companies, agencies, institutions, etc.
# three | 11927 | 11932 | CARDINAL | Numerals that do not fall under another type
# 1987 | 12106 | 12110 | DATE | Absolute or relative dates or periods
# 1990 | 12138 | 12142 | DATE | Absolute or relative dates or periods
# MHADA | 12170 | 12175 | ORG | Companies, agencies, institutions, etc.
# 1995 | 12212 | 12216 | DATE | Absolute or relative dates or periods
# 10 per cent | 12316 | 12327 | MONEY | Monetary values, including unit
# 16 | 12341 | 12343 | CARDINAL | Numerals that do not fall under another type
# Court | 12350 | 12355 | ORG | Companies, agencies, institutions, etc.
# three | 12458 | 12463 | CARDINAL | Numerals that do not fall under another type
# 10% | 12694 | 12697 | PERCENT | Percentage, including "%"
# 18% | 12703 | 12706 | PERCENT | Percentage, including "%"
# 17 | 12719 | 12721 | CARDINAL | Numerals that do not fall under another type
# Mcdermott International Inc. | 12750 | 12778 | ORG | Companies, agencies, institutions, etc.
# 154 | 12801 | 12804 | CARDINAL | Numerals that do not fall under another type
# 31(7)(a | 12955 | 12962 | CARDINAL | Numerals that do not fall under another type
# the Arbitral Tribunal | 12978 | 12999 | ORG | Companies, agencies, institutions, etc.
# The Arbitral Tribunal | 13560 | 13581 | ORG | Companies, agencies, institutions, etc.
# pre­award | 13849 | 13858 | PERSON | People, including fictional
# 155 | 13868 | 13871 | CARDINAL | Numerals that do not fall under another type
# 1996 | 13877 | 13881 | DATE | Absolute or relative dates or periods
# 18% | 13908 | 13911 | PERCENT | Percentage, including "%"
# 10% | 13963 | 13966 | PERCENT | Percentage, including "%"
# 18% | 14192 | 14195 | PERCENT | Percentage, including "%"
# 156 | 14208 | 14211 | CARDINAL | Numerals that do not fall under another type
# Court | 14242 | 14247 | ORG | Companies, agencies, institutions, etc.
# Article 142 | 14299 | 14310 | LAW | Named documents made into laws.
# 157 | 14365 | 14368 | CARDINAL | Numerals that do not fall under another type
# Pure Helium India | 14373 | 14390 | ORG | Companies, agencies, institutions, etc.
# 2003 | 14402 | 14406 | DATE | Absolute or relative dates or periods
# 18% | 14509 | 14512 | PERCENT | Percentage, including "%"
# p.a. | 14513 | 14517 | GPE | Countries, cities, states
# Article 142 of the Constitution of India | 14791 | 14831 | LAW | Named documents made into laws.
# 6% | 14900 | 14902 | PERCENT | Percentage, including "%"
# 18% | 14932 | 14935 | PERCENT | Percentage, including "%"
# p.a | 14936 | 14939 | ORG | Companies, agencies, institutions, etc.
# 158 | 14942 | 14945 | CARDINAL | Numerals that do not fall under another type
# Mukand Ltd. | 14960 | 14971 | ORG | Companies, agencies, institutions, etc.
# Hindustan Petroleum Corpn. | 14975 | 15001 | ORG | Companies, agencies, institutions, etc.
# 2006 | 15009 | 15013 | DATE | Absolute or relative dates or periods
# 2006 | 15028 | 15032 | DATE | Absolute or relative dates or periods
# 4 | 15034 | 15035 | CARDINAL | Numerals that do not fall under another type
# Court | 15059 | 15064 | ORG | Companies, agencies, institutions, etc.
# Court | 15179 | 15184 | ORG | Companies, agencies, institutions, etc.
# Single | 15229 | 15235 | ORG | Companies, agencies, institutions, etc.
# 11% | 15272 | 15275 | PERCENT | Percentage, including "%"
# 7½ % | 15289 | 15293 | PERCENT | Percentage, including "%"
# 7½ % | 15319 | 15323 | PERCENT | Percentage, including "%"
# 159 | 15486 | 15489 | CARDINAL | Numerals that do not fall under another type
# 7½ % | 15606 | 15610 | PERCENT | Percentage, including "%"
# 18 | 15614 | 15616 | CARDINAL | Numerals that do not fall under another type
# Article 142 of the Constitution of India | 15685 | 15725 | LAW | Named documents made into laws.
# Court | 15732 | 15737 | ORG | Companies, agencies, institutions, etc.
# 7.5% | 15774 | 15778 | PERCENT | Percentage, including "%"
# 19 | 15791 | 15793 | CARDINAL | Numerals that do not fall under another type
# Krishna Bhagya Jala Nigam Ltd. | 15817 | 15847 | ORG | Companies, agencies, institutions, etc.
# Court | 15862 | 15867 | ORG | Companies, agencies, institutions, etc.
# 11 | 15923 | 15925 | CARDINAL | Numerals that do not fall under another type
# 25­6­2000 | 16016 | 16025 | CARDINAL | Numerals that do not fall under another type
# 18% | 16628 | 16631 | PERCENT | Percentage, including "%"
# 9% | 16728 | 16730 | PERCENT | Percentage, including "%"
# 20 | 16733 | 16735 | CARDINAL | Numerals that do not fall under another type
# Court | 16873 | 16878 | ORG | Companies, agencies, institutions, etc.
# Article 142 of the Constitution of India | 16914 | 16954 | LAW | Named documents made into laws.
# three | 17329 | 17334 | CARDINAL | Numerals that do not fall under another type
# 21 | 17435 | 17437 | CARDINAL | Numerals that do not fall under another type
# August 1977 and 25th July 1989 | 17598 | 17628 | DATE | Absolute or relative dates or periods
# February 2000 | 17662 | 17675 | DATE | Absolute or relative dates or periods
# 15th October 2001 | 17680 | 17697 | DATE | Absolute or relative dates or periods
# three | 17753 | 17758 | CARDINAL | Numerals that do not fall under another type
# 9% | 17894 | 17896 | PERCENT | Percentage, including "%"
# 22 | 17909 | 17911 | CARDINAL | Numerals that do not fall under another type
# the Executing Court | 18029 | 18048 | ORG | Companies, agencies, institutions, etc.
# one month | 18124 | 18133 | DATE | Absolute or relative dates or periods
# The Executing Court | 18166 | 18185 | ORG | Companies, agencies, institutions, etc.
# a period of | 18263 | 18274 | DATE | Absolute or relative dates or periods
# one month | 18275 | 18284 | DATE | Absolute or relative dates or periods
# the Executing Court | 18366 | 18385 | ORG | Companies, agencies, institutions, etc.
# one month | 18405 | 18414 | DATE | Absolute or relative dates or periods
# 23 | 18428 | 18430 | CARDINAL | Numerals that do not fall under another type
# J.
#
# [ | 18559 | 18564 | PERSON | People, including fictional
# B.R. GAVAI] | 18564 | 18575 | ORG | Companies, agencies, institutions, etc.
# J.
#
# [ | 18602 | 18607 | PERSON | People, including fictional
# B.V. NAGARATHNA] NEW DELHI | 18607 | 18633 | ORG | Companies, agencies, institutions, etc.
# SEPTEMBER 30, 2022 | 18636 | 18654 | DATE | Absolute or relative dates or periods

# %%
type(doc.ents)
# Out:
# tuple

# %%
type(doc.ents[23]) #Span class in SpaCy
# Out:
# spacy.tokens.span.Span

# %%
#Visualising Named Entities with SpaCy
from spacy import displacy
displacy.render(doc, style='ent') #displacy.serve -- if not on Jupyter Notebook.
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">     REPORTABLE</br></br>            IN
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     THE SUPREME COURT OF INDIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>             CIVIL APPELLATE JURISDICTION</br></br>             CIVIL APPEAL NO. 8990 OF
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>EXECUTIVE ENGINEER (R AND B)</br>AND OTHERS                                    ...
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APPELLANT(S
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# )</br></br>                           VERSUS</br>GOKUL CHANDRA
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KANUNGO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (DEAD)</br>THR. HIS LRS.                                ...
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RESPONDENT(S
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# )</br></br>                         JUDGMENT</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     B.R. GAVAI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , J.</br></br>1. The appellants have challenged the judgment dated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18th April 2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  passed by the learned Single Judge of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the High Court of Orissa in Arbitration Appeal No.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , thereby dismissing the appeal filed by the appellants.</br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . The facts in brief giving rise to the present appeal are as under:</br></br>The respondent was awarded the contract for construction of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 kilometers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  missing link on NH­6 from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanjipani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kuntala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16th December 1971
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The work was to be completed within
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that is before
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  th
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 1972
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The contract amount was
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rs.4,59,330/­.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  However, the work could not be completed by the stipulated date and it was completed only on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30th August 1977
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , by which date, the respondent was already paid an amount of Rs.3,36,465/­.</br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . The respondent, on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25th July 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , issued a notice to the appellant regarding his claim. The said notice was replied to by the appellant on
# <

# %%
# Entities recognised by the spaCy NER
nlp_spacy.pipe_labels['ner']
# Out:
# ['CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART']

# %% [markdown]
# You can observe that the NER by Spacy is not perfect and may not work well with all kinds of text. That is why people develop custom NERs for specialised topics. For instance, [Opennyai](https://github.com/OpenNyAI/Opennyai) developed an [NER for Indian Court Judgements](https://github.com/Legal-NLP-EkStep/legal_NER) with customised entities that a spaCy NER doesn't recognise (PRECEDENT, STATUTE etc).

# %% [markdown]
# #  Building your own NERs <a class="anchor" id="customner"></a>

# %% [markdown]
# ## Rule-based NERs <a class="anchor" id="rulener"></a>
# Even spaCy "en_core_web_sm" is a rule based NER. Let's see few of the rules it follows:

# %%
doc = nlp_spacy("The share price of Tata Motors is INR 412.90")
displacy.render(doc, style='ent') #displacy.serve -- if not on Jupyter Notebook.
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The share price of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tata Motors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     INR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     412.90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </div></span>

# %%
doc = nlp_spacy("The share price of tata motors is $ 412.90")
displacy.render(doc, style='ent') #displacy.serve -- if not on Jupyter Notebook.
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The share price of tata motors is $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     412.90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %% [markdown]
# Clearly spaCy's NER uses these rules:
# 1. ORG entity has to start with a capital letter.
# 2. MONEY entity starts with $ character
#
# Similarly, we can also build our own rule based NERs. These rules can be based on Parts of Speech (POS), Regex etc., SpaCy's EntityRuler can be used to build a rule based NER. [Link](https://ner.pythonhumanities.com/02_01_spaCy_Entity_Ruler.html#introducing-complex-rules-and-variance-to-the-entityruler-advanced)

# %% [markdown]
# ## Machine Learning based NERs <a class="anchor" id="mlner"></a>
#
# ### BERT - Hugging Face NER
#
# It has been trained to recognize four types of entities: location (LOC), organizations (ORG), person (PER) and Miscellaneous (MISC).

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

# %%
nlp_bert = pipeline("ner", model=model, tokenizer=tokenizer)
ner_results = nlp_bert(sample_text)

# %%
print(ner_results)
# Out:
# [{'entity': 'B-MISC', 'score': 0.6289397, 'index': 9, 'word': 'S', 'start': 36, 'end': 37}, {'entity': 'B-LOC', 'score': 0.99272704, 'index': 17, 'word': 'IN', 'start': 53, 'end': 55}, {'entity': 'I-LOC', 'score': 0.773564, 'index': 18, 'word': '##DI', 'start': 55, 'end': 57}, {'entity': 'I-LOC', 'score': 0.93382025, 'index': 19, 'word': '##A', 'start': 57, 'end': 58}, {'entity': 'I-ORG', 'score': 0.45966476, 'index': 88, 'word': 'CH', 'start': 278, 'end': 280}, {'entity': 'I-ORG', 'score': 0.5811653, 'index': 89, 'word': '##AN', 'start': 280, 'end': 282}, {'entity': 'I-ORG', 'score': 0.5139487, 'index': 90, 'word': '##DR', 'start': 282, 'end': 284}, {'entity': 'I-ORG', 'score': 0.7135396, 'index': 92, 'word': 'K', 'start': 286, 'end': 287}, {'entity': 'I-ORG', 'score': 0.464004, 'index': 93, 'word': '##AN', 'start': 287, 'end': 289}, {'entity': 'B-PER', 'score': 0.96993154, 'index': 128, 'word': 'B', 'start': 398, 'end': 399}, {'entity': 'I-PER', 'score': 0.75982845, 'index': 130, 'word': 'R', 'start': 400, 'end': 401}, {'entity': 'I-PER', 'score': 0.982702, 'index': 132, 'word': 'GA', 'start': 403, 'end': 405}, {'entity': 'I-PER', 'score': 0.63431615, 'index': 133, 'word': '##VA', 'start': 405, 'end': 407}, {'entity': 'B-ORG', 'score': 0.9867561, 'index': 160, 'word': 'High', 'start': 525, 'end': 529}, {'entity': 'I-ORG', 'score': 0.97865766, 'index': 161, 'word': 'Court', 'start': 530, 'end': 535}, {'entity': 'I-ORG', 'score': 0.933501, 'index': 162, 'word': 'of', 'start': 536, 'end': 538}, {'entity': 'B-LOC', 'score': 0.9902858, 'index': 163, 'word': 'Or', 'start': 539, 'end': 541}, {'entity': 'I-ORG', 'score': 0.8170504, 'index': 164, 'word': '##issa', 'start': 541, 'end': 545}, {'entity': 'B-ORG', 'score': 0.3378962, 'index': 220, 'word': 'NH', 'start': 800, 'end': 802}, {'entity': 'B-LOC', 'score': 0.99557424, 'index': 223, 'word': 'Ka', 'start': 810, 'end': 812}, {'entity': 'I-LOC', 'score': 0.96691597, 'index': 224, 'word': '##nji', 'start': 812, 'end': 815}, {'entity': 'I-LOC', 'score': 0.8925769, 'index': 225, 'word': '##pan', 'start': 815, 'end': 818}, {'entity': 'I-LOC', 'score': 0.96818995, 'index': 226, 'word': '##i', 'start': 818, 'end': 819}, {'entity': 'B-LOC', 'score': 0.9959971, 'index': 228, 'word': 'Ku', 'start': 823, 'end': 825}, {'entity': 'I-LOC', 'score': 0.97866726, 'index': 229, 'word': '##ntal', 'start': 825, 'end': 829}, {'entity': 'I-LOC', 'score': 0.9887475, 'index': 230, 'word': '##a', 'start': 829, 'end': 830}]

# %% [markdown]
# SpaCy also has a transformer based NER model.
#
# Even a combination of ML and Rule based NER Models can be built.

# %% [markdown]
# # OpenNyai <a class="anchor" id="opennyai"></a>
#
# This is a custom NER developed by Ek-STEP to identify specialised entities from Indian Court Judgements. It is a transformer based NER but with custom rules.

# %%
from opennyai import Pipeline
from opennyai.utils import Data

# %%
#Sample court judgements
text1 = open('SampleTexts/sample_judgment1.txt').read()
text2 = open('SampleTexts/sample_judgment2.txt').read()

# you can also load your text files directly into this
texts_to_process = [text1, text2]

# %%
# create Data object for data  preprocessing before running ML models
data = Data(texts_to_process, preprocessing_nlp_model='en_core_web_trf')

#Other pre-processing models available are: en_core_web_md, en_core_web_sm (fastest but less accurate)
# Out:
# ℹ Pre-processing will happen on CPU!

# %% [markdown]
# The following pre-processing steps takes place with the above code:
# 1. Separating preamble from judgment text
# 2. Sentence splitting of judgment text
# 3. Convert upper case words in preamble to title case
# 4. Replace newline characters within a sentence with space in judgment text
#
# More on pre-processing: [Link](https://opennyai.readthedocs.io/en/latest/preprocessing/preprocessing.html) (chunks etc)

# %%
# If you have access to GPU then set this to True else False
use_gpu = False

# %%
# Load NER model
pipeline = Pipeline(components=['NER'], use_gpu=use_gpu, verbose=True,
                   ner_model_name='en_legal_ner_trf',
                   ner_mini_batch_size=40000,
                   ner_do_sentence_level=True,
                   ner_do_postprocess=True,
                   ner_statute_shortforms_path='')


#'en_legal_ner_sm’ is fast but less accurate.
# Out:
# ℹ Loading NER...
# ℹ NER will run on CPU!

# %%
#Apply NER pipeline over the data
results = pipeline(data)
# Out:
# ℹ Processing documents with Legal NER!!!
#  50%|██████████████████████▌                      | 1/2 [00:12<00:12, 12.94s/it]
# ⚠ There was some issue while performing postprocessing for doc id
# 38c4e8ad5395d9a57af900e8bd801d146c84a09d0a91703ca69a3ebeb5f5bece.
# Some of postprocessing info may be absent because of this in doc.
# 100%|█████████████████████████████████████████████| 2/2 [00:35<00:00, 17.56s/it]

# %%
# Export the results to a json file
import json
with open('output.json','w') as f:
     json.dumps(results,f,indent=4)

# %% [markdown]
# OpenNyai's NER performs at sentence level. So, all entities present in a particular sentence are stored in a dictionary. The first sentence of every judgement is "Preamble" by default.
#
# For more information on parameters: [Link](https://opennyai.readthedocs.io/en/latest/ner/legal_named_entities.html)
#
# Since the NER is done at sentence level, post processing will be helpful in capturing document level context. Post processing is done using rules.

# %%
# Entities identified in Preamble of 1st judgement
results[0]['annotations'][0]
# Out:
# {'id': '20f13480b7804b28a397c336e753f6ef',
#  'start': 0,
#  'end': 405,
#  'text': '     Reportable\n\n            In The Supreme Court Of India\n             Civil Appellate Jurisdiction \n\n             Civil Appeal No. 8990 Of 2017 \n\nExecutive Engineer (R And B)\nAnd Others                                    ... Appellant(S) \n\n                           Versus\nGokul Chandra Kanungo (Dead) \nThr. His Lrs.                                ... Respondent(S) \n\n                         Judgment\n',
#  'entities': [{'id': '204e0f2415924ef1affad2ac69f094f1',
#    'normalized_name': 'Supreme Court Of India',
#    'start': 36,
#    'end': 58,
#    'text': 'Supreme Court Of India',
#    'labels': ['COURT']},
#   {'id': 'dbb2d97e62204879a7dd726053503824',
#    'normalized_name': 'Executive Engineer',
#    'start': 148,
#    'end': 166,
#    'text': 'Executive Engineer',
#    'labels': ['PETITIONER']},
#   {'id': '61e0c69831ce476384c6c4bc6ea5dd7f',
#    'normalized_name': 'Gokul Chandra Kanungo',
#    'start': 276,
#    'end': 297,
#    'text': 'Gokul Chandra Kanungo',
#    'labels': ['RESPONDENT']}]}

# %%
results[0]['annotations'][76]
# Out:
# {'id': '1a629c5b51a04d2eb695f4f24fa887bb',
#  'start': 10799,
#  'end': 10926,
#  'text': 'It will be apposite to refer to the following observations of this Court in the case of Rajendra Construction Co. (supra):\n\n30.',
#  'entities': [{'id': '74bd7e9df8ad45e2b5b04331da3e9aa1',
#    'normalized_name': 'Rajendra Construction Co.',
#    'start': 10887,
#    'end': 10912,
#    'text': 'Rajendra Construction Co.',
#    'labels': ['ORG']}]}

# %%
ner_doc_1 = pipeline._ner_model_output[0]
identified_entites = [(ent, ent.label_) for ent in ner_doc_1.ents]
identified_entites
# Out:
# [(Supreme Court Of India, 'COURT'),
#  (Executive Engineer, 'PETITIONER'),
#  (Gokul Chandra Kanungo, 'RESPONDENT'),
#  (B.R. GAVAI, 'JUDGE'),
#  (18th April 2012, 'DATE'),
#  (High Court of Orissa, 'COURT'),
#  (Arbitration Appeal No. 25 of 2007, 'CASE_NUMBER'),
#  (Kanjipani, 'GPE'),
#  (Kuntala, 'GPE'),
#  (16th December 1971, 'DATE'),
#  (15 th December 1972, 'DATE'),
#  (30th August 1977, 'DATE'),
#  (25th July 1989, 'DATE'),
#  (10 th August 1989, 'DATE'),
#  (O.S. No. 206 of 1989, 'CASE_NUMBER'),
#  (Court of Civil Judge (Senior Division), Bhubaneswar, 'COURT'),
#  (Section 20, 'PROVISION'),
#  (Arbitration Act, 1940, 'STATUTE'),
#  (14th February 1990, 'DATE'),
#  (1940 Act, 'STATUTE'),
#  (Arbitration and Conciliation Act, 1996, 'STATUTE'),
#  (4th February 2000, 'DATE'),
#  (MJC No. 36 of 2000, 'CASE_NUMBER'),
#  (Section 11, 'PROVISION'),
#  (15 th October 2001, 'DATE'),
#  (S.K. Mohanty, 'JUDGE'),
#  (15th March 2002, 'DATE'),
#  (1st April 1976, 'DATE'),
#  (15th March 2002, 'DATE'),
#  (24 th August 2004, 'DATE'),
#  (1st April 1976, 'DATE'),
#  (Arbitration Petition No. 153 of 2004, 'CASE_NUMBER'),
#  (Court of District Judge, Cuttack, 'COURT'),
#  (Section 34, 'PROVISION'),
#  (25 th July 2007, 'DATE'),
#  (Section 37, 'PROVISION'),
#  (Sibo Sankar Mishra, 'OTHER_PERSON'),
#  (Ashok Panigrahi, 'OTHER_PERSON'),
#  (Mishra, 'OTHER_PERSON'),
#  (14th February 1990, 'DATE'),
#  (Rajendra Construction Co. v. Maharashtra Housing & Area Development Authority and Others 1,
#   'PRECEDENT'),
#  (Krishna Bhagya Jala Nigam Ltd. v. G. Harischandra Reddy and Another2,
#   'PRECEDENT'),
#  (Mcdermott International Inc. v. Burn Standard Co. Ltd. and Others3,
#   'PRECEDENT'),
#  (Panigrahi, 'OTHER_PERSON'),
#  ((2005) 6 SCC 678 2 (2007) 2 SCC 720 3 (2006) 11 SCC 181, 'PRECEDENT'),
#  (subsection (7) of Section 31, 'PROVISION'),
#  (Hyder Consulting (UK) Limited v. Governor, State of Orissa, 'PRECEDENT'),
#  (Section 31(7)(a), 'PROVISION'),
#  (Section 31(7)(a), 'PROVISION'),
#  (Hyder Consulting (UK) Limited, 'ORG'),
#  (Delhi Airport Metro Express Private Limited v. Delhi Metro Rail Corporation5,
#   'PRECEDENT'),
#  (clause (a) of sub section (7) of Section 31, 'PROVISION'),
#  (no 4 (2015) 2 SCC 189 5 2022 SCC OnLine SC 549, 'CASE_NUMBER'),
#  (30st August 1977, 'DATE'),
#  (25th July 1989, 'DATE'),
#  (25th July 1989, 'DATE'),
#  (14 th February 1990, 'DATE'),
#  (4 th February 2000, 'DATE'),
#  (4th February 2000, 'DATE'),
#  (MJC No. 36 of 2000, 'CASE_NUMBER'),
#  (Section 11, 'PROVISION'),
#  (1996 Act, 'STATUTE'),
#  (15 th October 2001, 'DATE'),
#  (14th February 1990, 'DATE'),
#  (14 th February 1990, 'DATE'),
#  (4th February 2000, 'DATE'),
#  (Section 11, 'PROVISION'),
#  (15 th October
#   2001,
#   'DATE'),
#  (14 th February 1990, 'DATE'),
#  (15th October 2001, 'DATE'),
#  (Rajendra Construction Co., 'ORG'),
#  (Executive Engineer, Dhenkanal Minor Irrigation Division v. N.C. Budharaj [(2001) 2 SCC 721],
#   'PRECEDENT'),
#  (Secy., Irrigation Deptt., Govt. of Orissa v. G.C. Roy [(1992) 1 SCC 508],
#   'PRECEDENT'),
#  (Hindustan Construction Co. Ltd. v. State of J&K [(1992) 4 SCC 217],
#   'PRECEDENT'),
#  (Bhagawati Oxygen Ltd. v. Hindustan Copper Ltd. [(2005) 6 SCC 462 : AIR 2005 SC 2071 :
#   JT (2005) 4 SC 73],
#   'PRECEDENT'),
#  (C.K. Thakker, 'JUDGE'),
#  (MHADA, 'ORG'),
#  (Mcdermott International Inc., 'ORG'),
#  (Section 31(7)(a), 'PROVISION'),
#  (Article 142, 'PROVISION'),
#  (Pure Helium India (P) Ltd. [(2003) 8 SCC 593], 'PRECEDENT'),
#  (Article 142, 'PROVISION'),
#  (Constitution of India, 'STATUTE'),
#  (Mukand Ltd. v. Hindustan Petroleum Corpn. Ltd. [(2006) 9 SCC 383 : (2006) 4 Scale 453],
#   'PRECEDENT'),
#  (Article 142, 'PROVISION'),
#  (Constitution of India, 'STATUTE'),
#  (Krishna Bhagya Jala Nigam Ltd., 'ORG'),
#  (Article 142, 'PROVISION'),
#  (Constitution of India, 'STATUTE'),
#  (30 th August 1977, 'DATE'),
#  (25th July 1989, 'DATE'),
#  (14 th February 2000, 'DATE'),
#  (15th October 2001, 'DATE'),
#  (B.R. GAVAI, 'JUDGE'),
#  (B.V. NAGARATHNA, 'JUDGE'),
#  (NEW DELHI, 'GPE'),
#  (SEPTEMBER 30, 2022, 'DATE')]

# %% [markdown]
# Entities that are identified by Opennyai's NER: COURT, PETITIONER, RESPONDENT, JUDGE, LAWYER, DATE, ORG, GPE, STATUTE, PROVISION, PRECEDENT, CASE_NUMBER, WITNESS, OTHER_PERSON. These are better explained here: [Link](https://docs.google.com/presentation/d/e/2PACX-1vSpWE_Qk9X_wBh7xJWPyYcWcME3ZBh_HmqeZOx58oMLyJSi0Tn0-JMWKI-HsQIRuUTbQHPql6MlU7OS/pub?start=false&loop=false&delayms=3000#slide=id.g13cb659750e_0_76)
#
# Hence, it is much more specialised than general purpose NERs.

# %%
type(ner_doc_1.ents[0])
# Out:
# spacy.tokens.span.Span

# %%
#Visualising NER
from spacy import displacy
from opennyai.ner.ner_utils import ner_displacy_option
#displacy.serve(ner_doc_1, style='ent',port=8080,options=ner_displacy_option)
displacy.render(ner_doc_1, style='ent', options=ner_displacy_option)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">     Reportable</br></br>            In The
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Supreme Court Of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
# </br>             Civil Appellate Jurisdiction </br></br>             Civil Appeal No. 8990 Of 2017 </br></br>
# <mark class="entity" style="background: #f570ea; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Executive Engineer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PETITIONER</span>
# </mark>
#  (R And B)</br>And Others                                    ... Appellant(S) </br></br>                           Versus</br>
# <mark class="entity" style="background: #cdee81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gokul Chandra Kanungo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">RESPONDENT</span>
# </mark>
#  (Dead) </br>Thr. His Lrs.                                ... Respondent(S) </br></br>                         Judgment</br>
# <mark class="entity" style="background: #fdd8a5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     B.R. GAVAI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JUDGE</span>
# </mark>
# , J.</br></br>1. The appellants have challenged the judgment dated
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18th April 2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  passed by the learned Single Judge of the
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     High Court of Orissa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
#  in
# <mark class="entity" style="background: #fbb1cf; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arbitration Appeal No. 25 of 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASE_NUMBER</span>
# </mark>
# , thereby dismissing the appeal filed by the appellants. </br></br>2. The facts in brief giving rise to the present appeal are as under:</br></br>The respondent was awarded the contract for construction of 3 kilometers missing link on NH6 from
# <mark class="entity" style="background: #7fdbd4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanjipani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #7fdbd4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kuntala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16th December 1971
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The work was to be completed within one year that is before
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 th December 1972
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The contract amount was Rs.4,59,330/. However, the work could not be completed by the stipulated date and it was completed only on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30th August 1977
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , by which date, the respondent was already paid an amount of Rs.3,36,465/. </br></br>3. The respondent, on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25th July 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , issued a notice to the appellant regarding his claim. The said notice was replied to by the appellant on
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 th August 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  stating therein that, as against the claim of Rs.3,34,744/, the respondent had been paid an amount of Rs.3,36,465/. The respondent thereafter filed a suit being
# <mark class="entity" style="background: #fbb1cf; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     O.S. No. 206 of 1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASE_NUMBER</span>
# </mark>
#  before the
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Court of Civil Judge (Senior Division), Bhubaneswar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
#  (hereinafter referred to as the trial court) under
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Section 20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROVISION</span>
# </mark>
#  of the
# <mark class="entity" style="background: #faea99; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arbitration Act, 1940
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUTE</span>
# </mark>
#  (for short, the 1940 Act) seeking reference of the dispute to arbitration. By order of the trial court dated
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14th February 1990
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the suit was decreed in favour of the respondent and he was directed to file the original F2 agreement in the court for referring the dispute to arbitration. However, the respondent did not file the original F2 agreement as directed. In the meantime, the
# <mark class="entity" style="background: #faea99; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em

# %%
# Frequency count of all precendents in a judgement
#from opennyai.ner import get_unique_precedent_count
#import opennyai.ner as InLegalNER

#precedents=InLegalNER.get_unique_precedent_count(ner_doc_1)
#precedents

# %%
# Frequency count of all provisions in a judgement
from opennyai.ner import get_unique_provision_count
provisions=get_unique_provision_count(ner_doc_1)
provisions
# Out:
# {'Section 20 of Arbitration Act, 1940': 1,
#  'Article 142 of Constitution of India': 4,
#  'Section 11 of 1996 Act': 3,
#  'Section 34 of 1996 Act': 1,
#  'Section 37 of 1996 Act': 1,
#  'subsection (7) of Section 31 of 1996 Act': 1,
#  'Section 31(7)(a) of 1996 Act': 3,
#  'clause (a) of sub section (7) of Section 31 of 1996 Act': 1}

# %%
# Frequency count of all statues in a judgement
from opennyai.ner import get_unique_statute_count
statutes=get_unique_statute_count(ner_doc_1)
statutes
# Out:
# {'Arbitration Act, 1940': 1, 'Constitution of India': 4, '1996 Act': 10}

# %%
# Saving NER Results
from opennyai.ner import get_csv
get_csv(ner_doc_1,'sample_judgement1_NER.csv', save_path=r"/home/krishna/NLP/NER/sample_judgement1_NER.csv")

# %% [markdown]
# # References
# 1. [NLP Tutorial by Codebasics](https://www.youtube.com/watch?v=2XUhKpH0p4M)
# 2. [Huggingface NER](https://huggingface.co/dslim/bert-base-NER)
# 3. [Creating your own rule based NER using SpaCy](https://ner.pythonhumanities.com/02_01_spaCy_Entity_Ruler.html#introducing-complex-rules-and-variance-to-the-entityruler-advanced)
# 4. [Opennyai - NER](https://github.com/Legal-NLP-EkStep/legal_NER)
